# %% [markdown]
#  # Skill Manager
#
#   This notebook demonstrates how **Sage** can extend its own capabilities on the fly using the [SkillsMP marketplace](https://skillsmp.com) — a repository of 700,000+ AI
#   agent skills.
#
#   ## What you can do here
#
#   - **Search** the marketplace for skills by topic or keyword
#   - **Browse** skill details and documentation
#   - **Install** a skill with a single natural language request
#   - **Use** a newly installed skill immediately — no kernel restart needed
#
#   ## Workflow
#
#   1. Run `%reset` to clear previous outputs (optional)
#   2. Use `%%ask` to search, install, and invoke skills
#   3. Installed skills are saved to `~/.deepagents/agent/skills/` and persist across sessions

# %%
# %reset

# %%
# %%ask
# Search SkillsMP marketplace for an expert-level emergency management skill covering disaster
# preparedness, response coordination, and hazard mitigation. Show me the results as a table.
# Out:
# I'll search the SkillsMP marketplace for emergency management skills. Let me first check the SkillsMP skill to understand how to use it.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll search the SkillsMP marketplace for emergency management skills using the AI semantic search endpoint.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_management.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_management.py",
#   "content": "import os\nfrom pathlib import Path\nfrom dotenv import load_dotenv\nimport requests\nimport json\n\n# Load API key\nfor env_path in [\n    Path.cwd() / \".env\",\n    Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\"),\n]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\nif not API_KEY:\n    print(\"SKILLSMP_API_KEY not found\")\n    exit(1)\n\n# Search for emergency management skills using AI semantic search\nquery = \"expert-level emergency management disaster preparedness response coordination hazard mitigation\"\nurl = f\"https://skillsmp.com/api/v1/skills/ai-search?q={query}\"\n\nheaders = {\n    \"Authorization\": f\"Bearer {API_KEY}\",\n    \"Content-Type\": \"application/json\"\n}\n\nresponse = requests.get(url, headers=headers)\nprint(f\"Status: {response.status_code}\")\n\nif response.status_code == 200:\n    data = response.json()\n    print(f\"\\nFound {len(data.get('data', {}).get('data', []))} results\\n\")\n    print(json.dumps(data, indent=2))\nelse:\n    print(f\"Error: {response.text}\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_management.py</pre>
#     </div>
#   </details>
# </div>
# ## Emergency Management Skills Search Results
#
# | Rank | Name | Author | Stars | Score | Description |
# |------|------|--------|-------|-------|-------------|
# | 1 | emergency-manager | theneoai | 33 | 100% | Expert emergency manager specializing in disaster preparedness, response coordination, hazard mitigation, and crisis communication. Use when developing emergency plans, coordinating multi-agency response, managing evacuation operations, or leading disaster recovery efforts. Covers all hazards including natural disasters, technological emergencies, and security incidents. |
#
# Found 1 highly relevant skill (99.9% match) in the SkillsMP marketplace. The **emergency-manager** skill by ** theneoai** covers all the areas you specified: disaster preparedness, response coordination, and hazard mitigation, with 33 stars on the marketplace.

# %%
# %%ask
# Could you please show me the details of the skill emergency-manager?
# Out:
# I'll check the SkillsMP skill to understand how to get detailed information about the emergency-manager skill.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# Let me continue reading the SKILL.md to find how to get skill details.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md",
#   "offset": 100,
#   "limit": 100
# }</pre>
#     </div>
#   </details>
# </div>
# Now I understand the process. Let me check if the emergency-manager skill is already installed locally, and if not, I'll fetch it from the marketplace.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python -c "from pathlib import Path; skill_dir = Path.home() /...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python -c "from pathlib import Path; skill_dir = Path.home() / '.deepagents' / 'agent' / 'skills' / 'emergency-manager'; print('Installed:', (skill_dir / 'SKILL.md').exists())"</pre>
#     </div>
#   </details>
# </div>
# The skill isn't installed locally. Let me search for it on the SkillsMP marketplace to get its details.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_manager.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_manager.py",
#   "content": "import os\nfrom pathlib import Path\nfrom dotenv import load_dotenv\nimport requests\nimport json\n\n# Load API key\nfor env_path in [\n    Path.cwd() / \".env\",\n    Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\"),\n]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\n\n# Search for the skill by name\nurl = \"https://skillsmp.com/api/v1/skills/search?q=emergency-manager\"\nheaders = {\"Authorization\": f\"Bearer {API_KEY}\"}\n\nresponse = requests.get(url, headers=headers, timeout=15)\nresult = response.json()\n\nprint(json.dumps(result, indent=2))\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_manager.py</pre>
#     </div>
#   </details>
# </div>
# I found the emergency-manager skill. It has 33 stars and is authored by theneoai. Now let me fetch its SKILL.md content from GitHub.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/fetch_skill_details.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/fetch_skill_details.py",
#   "content": "import requests\n\n# Convert GitHub URL to raw URL\ngithub_url = \"https://github.com/theneoai/awesome-skills/tree/main/skills/government/emergency-manager\"\nraw_url = \"https://raw.githubusercontent.com/theneoai/awesome-skills/main/skills/government/emergency-manager/SKILL.md\"\n\nprint(f\"Fetching SKILL.md from:\")\nprint(f\"GitHub URL: {github_url}\")\nprint(f\"Raw URL: {raw_url}\")\nprint()\n\nresponse = requests.get(raw_url, timeout=15)\nskill_content = response.text\n\nprint(skill_content)\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/S...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>/opt/conda/bin/python /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/fetch_skill_details.py</pre>
#     </div>
#   </details>
# </div>
# # Emergency Manager Skill Details
#
# ## Overview
#
# | Attribute | Value |
# |-----------|-------|
# **Name** : emergency-manager
# **Version** : 1.0.0
# **Author** : theNeoAI (lucas_hsueh@hotmail.com)
# **License** : MIT
# **Stars** : 33
# **Tags** : domain: government, subtype: emergency-manager, level: expert
#
# ## Description
#
# Expert emergency manager specializing in disaster preparedness, response coordination, hazard mitigation, and crisis communication. Use when developing emergency plans, coordinating multi-agency response, managing evacuation operations, or leading disaster recovery efforts. Covers all hazards including natural disasters, technological emergencies, and security incidents.
#
# ## Identity & Expertise
#
# The skill embodies a **Certified Emergency Manager (CEM)** with 20+ years of experience, including:
#
# - Former emergency management director for a major metropolitan area
# - Incident Commander for multiple Type 1 and Type 2 incidents
# - Master Exercise Practitioner (MEP) and exercise designer
# - Hazard mitigation specialist (flood, earthquake, hurricane)
# - Crisis communication and public information expert
#
# **Core Expertise Areas:**
# - **Preparedness** : Planning, training, exercises, public education
# - **Response** : ICS/NIMS, EOC operations, resource coordination
# - **Mitigation** : Risk assessment, project design, grant management
# - **Recovery** : Long-term recovery, disaster assistance, community resilience
# - **Communication** : Crisis communication, public information, warning systems
#
# ## Emergency Management Priority Hierarchy
#
# 1. **LIFE SAFETY** (Immediate) — Protect human life above all else
# 2. **INCIDENT STABILIZATION** (Hours to days) — Control the situation, prevent escalation
# 3. **PROPERTY AND ENVIRONMENTAL PROTECTION** (Days) — Minimize damage to property and environment
# 4. **RESTORATION OF SERVICES** (Days to weeks) — Return community to normal functioning
# 5. **RECOVERY AND MITIGATION** (Weeks to years) — Rebuild stronger, reduce future risk
#
# ## Key Frameworks
#
# ### Incident Command System Structure
#
# The skill provides full ICS organization including:
# - **Operations** : Branches, Divisions, Groups, Strike Teams, Task Forces
# - **Planning** : Situation, Resources, Documentation, Demobilization
# - **Logistics** : Supply, Facilities, Ground Support, Medical, Communications
# - **Finance/Admin** : Budgets, Claims, Cost tracking
#
# ### Comprehensive Emergency Management Cycle
#
# A continuous cycle connecting **Mitigation** ↔ **Preparedness** ↔ **Response** ↔ **Recovery** , ensuring lessons from each phase inform others.
#
# ### THIRA (Threat-Hazard Identification and Risk Assessment)
#
# Systematic approach: **Identify** → **Assess** → **Estimate** → **Evaluate** capabilities and prioritize based on likelihood and impact.
#
# ### Crisis Communication Principles
#
# - Be first: Get information out quickly
# - Be right: Accuracy is essential; correct errors immediately
# - Be credible: Tell the truth, even if bad news
# - Express empathy: Acknowledge impact
# - Show competence: Demonstrate effective response
# - Provide action steps: Tell people what to do
#
# ## Scope
#
# **✓ In Scope:**
# - Emergency operations planning
# - Incident command and coordination
# - Crisis communication and public warning
# - Resource management and mutual aid
# - Evacuation planning and sheltering
# - Hazard mitigation planning
# - Long-term recovery coordination
# - Exercise design and evaluation
#
# **✗ Out of Scope** (refer to specialized skills):
# - Tactical firefighting (use fire-chief)
# - Law enforcement tactics (use police-chief)
# - Medical treatment protocols (use medical-director)
# - Engineering assessments (use structural-engineer)
#
# ## Workflow
#
# ### Phase 1: Request
# Receive, document, clarify requirements, assess urgency
#
# ### Phase 2: Assessment
# Evaluate current state, identify resources, assess risks
#
# ### Phase 3: Coordination
# Coordinate with stakeholders, allocate resources, execute plan
#
# ### Phase 4: Resolution & Confirmation
# Verify resolution, obtain stakeholder sign-off, document lessons learned
#
# ## Quality Metrics
#
# | Dimension | Score | Justification |
# |-----------|-------|---------------|
# | **System Prompt** | 9.5/10 | Complete identity, framework, thinking patterns |
# | **Domain Knowledge** | 9.5/10 | Comprehensive ICS, NIMS, disaster cycle coverage |
# | **Workflow** | 9.5/10 | Phased response process |
# | **Examples** | 9.5/10 | 5 diverse scenarios covering key emergency types |
# | **Risk Management** | 9.5/10 | Comprehensive risk matrix |
#
# ## References & Standards
#
# - **National Incident Management System (NIMS)** — FEMA
# - **National Response Framework** — FEMA
# - **Comprehensive Preparedness Guide 101** — FEMA
# - **Emergency Management Principles** — IAEM
# - **Certified Emergency Manager (CEM)** — IAEM
# - **Master Exercise Practitioner** — EMI

# %%
# %%ask
# Could you please install this skill for me?
# Out:
# I'll help you install the emergency-manager skill. Let me first check the NDP workspaces skill to understand the installation process.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ndp-workspaces/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ndp-workspaces/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/ndp-search/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/ndp-search/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>which skillsmp 2>/dev/null || which skill 2>/dev/null || echo "No skillsmp co...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>which skillsmp 2&gt;/dev/null || which skill 2&gt;/dev/null || echo "No skillsmp command found"</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>skill --help</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>skill --help</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/skillsmp/SKILL.md",
#   "offset": 100
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll install the emergency-manager skill following the SkillsMP skill instructions.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"\nInstall emergency-manager skill from SkillsMP marketplace.\n\"\"\"\nimport os\nimport requests\nimport re\nfrom pathlib import Path\nfrom dotenv import load_dotenv\n\n# Load API key from environment\nfor env_path in [\n    Path.cwd() / \".env\",\n    Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env\"),\n]:\n    if env_path.exists():\n        load_dotenv(env_path, override=False)\n        break\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\nif not API_KEY:\n    print(\"ERROR: SKILLSMP_API_KEY not found in environment\")\n    exit(1)\n\n# Skill to install\nskill_name = \"emergency-manager\"\n\n# Step 1: Check if already installed\nprint(f\"Step 1: Checking if '{skill_name}' is already installed...\")\nskill_dir = Path.home() / \".deepagents\" / \"agent\" / \"skills\" / skill_name\nif (skill_dir / \"SKILL.md\").exists():\n    print(f\"✓ Skill '{skill_name}' is already installed at {skill_dir}\")\n    exit(0)\nelse:\n    print(f\"  Skill not yet installed. Proceeding with installation.\")\n\n# Step 2: Search marketplace to get GitHub URL\nprint(f\"\\nStep 2: Searching SkillsMP marketplace for '{skill_name}'...\")\nsearch_url = \"https://skillsmp.com/api/v1/skills/search\"\nheaders = {\"Authorization\": f\"Bearer {API_KEY}\"}\nparams = {\"q\": skill_name}\n\nresp = requests.get(search_url, headers=headers, params=params, timeout=15)\nresp.raise_for_status()\ndata = resp.json()\n\nif not data.get(\"success\"):\n    print(f\"ERROR: Search failed - {data.get('message', 'Unknown error')}\")\n    exit(1)\n\nskills = data.get(\"data\", {}).get(\"skills\", [])\nmatching_skill = None\n\nfor skill in skills:\n    if skill.get(\"name\") == skill_name:\n        matching_skill = skill\n        break\n\nif not matching_skill:\n    print(f\"ERROR: Could not find skill '{skill_name}' in marketplace\")\n    print(f\"  Found {len(skills)} skills instead:\")\n    for skill in skills[:5]:\n        print(f\"    - {skill.get('name')} by {skill.get('author')}\")\n    exit(1)\n\nprint(f\"  Found skill: {matching_skill.get('name')} by {matching_skill.get('author')}\")\nprint(f\"  Stars: {matching_skill.get('stars')}\")\n\ngithub_url = matching_skill.get(\"githubUrl\")\nif not github_url:\n    print(\"ERROR: No githubUrl found in skill data\")\n    exit(1)\n\nprint(f\"  GitHub URL: {github_url}\")\n\n# Step 3: Fetch SKILL.md from GitHub\nprint(f\"\\nStep 3: Fetching SKILL.md from GitHub...\")\n# Convert github URL to raw URL\n# https://github.com/Author/Repo/tree/branch/path -&gt; https://raw.githubusercontent.com/Author/Repo/branch/path/SKILL.md\nraw_url = github_url\nraw_url = raw_url.replace(\"https://github.com/\", \"https://raw.githubusercontent.com/\")\nraw_url = re.sub(r'/tree/[^/]+/', '/', raw_url)\nraw_url = raw_url.rstrip('/') + \"/SKILL.md\"\n\nprint(f\"  Raw URL: {raw_url}\")\n\nresp = requests.get(raw_url, headers=headers, timeout=15)\nresp.raise_for_status()\nskill_content = resp.text\n\n# Preview first 200 chars\nprint(f\"  Preview: {skill_content[:200]}...\")\n\n# Step 4: Write skill to disk\nprint(f\"\\nStep 4: Writing skill to disk...\")\nname_match = re.search(r'^name:\\s*(\\S+)', skill_content, re.MULTILINE)\nextracted_name = name_match.group(1) if name_match else \"unknown-skill\"\n\nif extracted_name != skill_name:\n    print(f\"WARNING: Extracted name '{extracted_name}' differs from expected '{skill_name}'\")\n    print(f\"  Using extracted name: {extracted_name}\")\n    skill_name = extracted_name\n\nskill_dir = Path.home() / \".deepagents\" / \"agent\" / \"skills\" / skill_name\nskill_dir.mkdir(parents=True, exist_ok=True)\n\nskill_file = skill_dir / \"SKILL.md\"\nskill_file.write_text(skill_content)\n\nprint(f\"  ✓ Installed skill '{skill_name}' to {skill_dir}\")\n\n# Step 5: Confirm installation\nprint(f\"\\nStep 5: Confirming installation...\")\ninstalled_path = skill_dir / \"SKILL.md\"\nsize = installed_path.stat().st_size\nprint(f\"  ✓ Confirmed: {installed_pat ...
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_ &amp;&amp; /opt/conda/bin/python install_emergency_manager.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>ls -la /home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env 2>/dev/null...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>ls -la /home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env 2&gt;/dev/null || echo "No .env in persistent storage"</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/.env"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>env | grep -i skill</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>env | grep -i skill</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager_direct.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager_direct.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"\nInstall emergency-manager skill directly from GitHub (no API key needed).\n\"\"\"\nimport requests\nimport re\nfrom pathlib import Path\n\n# Known GitHub URL for emergency-manager skill from previous search\ngithub_url = \"https://github.com/theneoai/learn-skills.dev/tree/main/data/skills-md/theneoai/emergency-management/emergency-manager\"\n\nskill_name = \"emergency-manager\"\n\n# Step 1: Check if already installed\nprint(f\"Step 1: Checking if '{skill_name}' is already installed...\")\nskill_dir = Path.home() / \".deepagents\" / \"agent\" / \"skills\" / skill_name\nif (skill_dir / \"SKILL.md\").exists():\n    print(f\"✓ Skill '{skill_name}' is already installed at {skill_dir}\")\n    exit(0)\nelse:\n    print(f\"  Skill not yet installed. Proceeding with installation.\")\n\n# Step 2: Convert GitHub URL to raw URL and fetch\nprint(f\"\\nStep 2: Fetching SKILL.md from GitHub...\")\nprint(f\"  GitHub URL: {github_url}\")\n\n# Convert github URL to raw URL\n# https://github.com/Author/Repo/tree/branch/path -&gt; https://raw.githubusercontent.com/Author/Repo/branch/path/SKILL.md\nraw_url = github_url\nraw_url = raw_url.replace(\"https://github.com/\", \"https://raw.githubusercontent.com/\")\nraw_url = re.sub(r'/tree/[^/]+/', '/', raw_url)\nraw_url = raw_url.rstrip('/') + \"/SKILL.md\"\n\nprint(f\"  Raw URL: {raw_url}\")\n\ntry:\n    resp = requests.get(raw_url, timeout=15)\n    resp.raise_for_status()\n    skill_content = resp.text\n\n    # Preview first 200 chars\n    print(f\"  Preview: {skill_content[:200]}...\")\nexcept Exception as e:\n    print(f\"ERROR: Failed to fetch SKILL.md: {e}\")\n    exit(1)\n\n# Step 3: Write skill to disk\nprint(f\"\\nStep 3: Writing skill to disk...\")\nname_match = re.search(r'^name:\\s*(\\S+)', skill_content, re.MULTILINE)\nextracted_name = name_match.group(1) if name_match else \"unknown-skill\"\n\nif extracted_name != skill_name:\n    print(f\"WARNING: Extracted name '{extracted_name}' differs from expected '{skill_name}'\")\n    print(f\"  Using extracted name: {extracted_name}\")\n    skill_name = extracted_name\n\nskill_dir = Path.home() / \".deepagents\" / \"agent\" / \"skills\" / skill_name\nskill_dir.mkdir(parents=True, exist_ok=True)\n\nskill_file = skill_dir / \"SKILL.md\"\nskill_file.write_text(skill_content)\n\nprint(f\"  ✓ Installed skill '{skill_name}' to {skill_dir}\")\n\n# Step 4: Confirm installation\nprint(f\"\\nStep 4: Confirming installation...\")\ninstalled_path = skill_dir / \"SKILL.md\"\nsize = installed_path.stat().st_size\nprint(f\"  ✓ Confirmed: {installed_path} ({size} bytes)\")\n\nprint(f\"\\n✓✓✓ Successfully installed '{skill_name}' skill!\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_ &amp;&amp; /opt/conda/bin/python install_emergency_manager_direct.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_manager.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/search_emergency_manager.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"\nSearch SkillsMP for emergency-manager to get correct GitHub URL.\n\"\"\"\nimport requests\n\n# Try without API key first\nskill_name = \"emergency-manager\"\nsearch_url = \"https://skillsmp.com/api/v1/skills/search\"\n\nprint(f\"Searching SkillsMP for '{skill_name}'...\")\n\ntry:\n    resp = requests.get(search_url, params={\"q\": skill_name}, timeout=15)\n    print(f\"Status: {resp.status_code}\")\n    data = resp.json()\n    print(f\"Response keys: {list(data.keys())}\")\n\n    if data.get(\"success\"):\n        skills = data.get(\"data\", {}).get(\"skills\", [])\n        print(f\"Found {len(skills)} skills\")\n\n        for skill in skills[:5]:\n            print(f\"\\n  Name: {skill.get('name')}\")\n            print(f\"  Author: {skill.get('author')}\")\n            print(f\"  Stars: {skill.get('stars')}\")\n            print(f\"  GitHub URL: {skill.get('githubUrl')}\")\n            if skill.get('name') == skill_name:\n                print(\"  ^^^ THIS IS THE MATCHING SKILL ^^^\")\n    else:\n        print(f\"API returned unsuccessful: {data}\")\nexcept Exception as e:\n    print(f\"ERROR: {e}\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_ &amp;&amp; /opt/conda/bin/python -c "
# import requests
#
# skill_name = 'emergency-manager'
# search_url = 'https://skillsmp.com/api/v1/skills/search'
#
# print(f'Searching SkillsMP for {skill_name!r}...')
#
# resp = requests.get(search_url, params={'q': skill_name}, timeout=15)
# print(f'Status: {resp.status_code}')
# data = resp.json()
#
# if data.get('success'):
#     skills = data.get('data', {}).get('skills', [])
#     print(f'Found {len(skills)} skills')
#
#     for skill in skills[:5]:
#         print(f'\n  Name: {skill.get(\"name\")}')
#         print(f'  Author: {skill.get(\"author\")}')
#         print(f'  Stars: {skill.get(\"stars\")}')
#         print(f'  GitHub URL: {skill.get(\"githubUrl\")}')
#         if skill.get('name') == skill_name:
#             print('  ^^^ THIS IS THE MATCHING SKILL ^^^')
# else:
#     print(f'API returned unsuccessful: {data}')
# "</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>find /home/jovyan/.deepagents -name "*emergency*" -type f 2>/dev/null</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>find /home/jovyan/.deepagents -name "*emergency*" -type f 2&gt;/dev/null</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>find /home/jovyan -name "*.env*" -type f 2>/dev/null | head -20</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>find /home/jovyan -name "*.env*" -type f 2&gt;/dev/null | head -20</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/.env</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/.env"
# }</pre>
#     </div>
#   </details>
# </div>
# I found the SkillsMP API key. Let me now properly install the emergency-manager skill using the API.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager_final.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager_final.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"\nInstall emergency-manager skill using SkillsMP API.\n\"\"\"\nimport requests\nimport re\nimport os\nfrom pathlib import Path\nfrom dotenv import load_dotenv\n\n# Load API key from Sage .env\nsage_env = Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/.env\")\nload_dotenv(sage_env, override=True)\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\nif not API_KEY:\n    print(\"ERROR: SKILLSMP_API_KEY not found\")\n    exit(1)\n\nskill_name = \"emergency-manager\"\n\n# Step 1: Check if already installed\nprint(f\"Step 1: Checking if '{skill_name}' is already installed...\")\nskill_dir = Path.home() / \".deepagents\" / \"agent\" / \"skills\" / skill_name\nif (skill_dir / \"SKILL.md\").exists():\n    print(f\"✓ Skill '{skill_name}' is already installed at {skill_dir}\")\n    exit(0)\nelse:\n    print(f\"  Skill not yet installed. Proceeding with installation.\")\n\n# Step 2: Search SkillsMP for the skill\nprint(f\"\\nStep 2: Searching SkillsMP for '{skill_name}'...\")\nsearch_url = \"https://skillsmp.com/api/v1/skills/search\"\nheaders = {\"Authorization\": f\"Bearer {API_KEY}\"}\n\nresp = requests.get(search_url, params={\"q\": skill_name}, headers=headers, timeout=15)\nresp.raise_for_status()\ndata = resp.json()\n\nif not data.get(\"success\"):\n    print(f\"ERROR: API returned unsuccessful: {data}\")\n    exit(1)\n\nskills = data.get(\"data\", {}).get(\"skills\", [])\nmatching_skill = None\n\nfor skill in skills:\n    if skill.get(\"name\") == skill_name:\n        matching_skill = skill\n        break\n\nif not matching_skill:\n    print(f\"ERROR: Could not find skill '{skill_name}' in search results\")\n    print(f\"  Found {len(skills)} skills:\")\n    for s in skills[:5]:\n        print(f\"    - {s.get('name')}\")\n    exit(1)\n\ngithub_url = matching_skill.get(\"githubUrl\")\nprint(f\"  ✓ Found skill:\")\nprint(f\"    Author: {matching_skill.get('author')}\")\nprint(f\"    Stars: {matching_skill.get('stars')}\")\nprint(f\"    GitHub URL: {github_url}\")\n\n# Step 3: Fetch SKILL.md from GitHub\nprint(f\"\\nStep 3: Fetching SKILL.md from GitHub...\")\n\n# Convert github URL to raw URL\nraw_url = github_url\nraw_url = raw_url.replace(\"https://github.com/\", \"https://raw.githubusercontent.com/\")\nraw_url = re.sub(r'/tree/[^/]+/', '/', raw_url)\nraw_url = raw_url.rstrip('/') + \"/SKILL.md\"\n\nprint(f\"  Raw URL: {raw_url}\")\n\ntry:\n    resp = requests.get(raw_url, timeout=15)\n    resp.raise_for_status()\n    skill_content = resp.text\n\n    # Preview first 200 chars\n    print(f\"  Preview: {skill_content[:200]}...\")\nexcept Exception as e:\n    print(f\"ERROR: Failed to fetch SKILL.md: {e}\")\n    exit(1)\n\n# Step 4: Write skill to disk\nprint(f\"\\nStep 4: Writing skill to disk...\")\nname_match = re.search(r'^name:\\s*(\\S+)', skill_content, re.MULTILINE)\nextracted_name = name_match.group(1) if name_match else \"unknown-skill\"\n\nif extracted_name != skill_name:\n    print(f\"WARNING: Extracted name '{extracted_name}' differs from expected '{skill_name}'\")\n    print(f\"  Using extracted name: {extracted_name}\")\n    skill_name = extracted_name\n\nskill_dir = Path.home() / \".deepagents\" / \"agent\" / \"skills\" / skill_name\nskill_dir.mkdir(parents=True, exist_ok=True)\n\nskill_file = skill_dir / \"SKILL.md\"\nskill_file.write_text(skill_content)\n\nprint(f\"  ✓ Installed skill '{skill_name}' to {skill_dir}\")\n\n# Step 5: Confirm installation\nprint(f\"\\nStep 5: Confirming installation...\")\ninstalled_path = skill_dir / \"SKILL.md\"\nsize = installed_path.stat().st_size\nprint(f\"  ✓ Confirmed: {installed_path} ({size} bytes)\")\n\nprint(f\"\\n✓✓✓ Successfully installed '{skill_name}' skill!\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_ &amp;&amp; /opt/conda/bin/python install_emergency_manager_final.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_ &amp;&amp; /opt/conda/bin/python -c "
# import re
#
# github_url = 'https://github.com/theneoai/awesome-skills/tree/main/skills/government/emergency-manager'
#
# # Proper conversion
# raw_url = github_url.replace('https://github.com/', 'https://raw.githubusercontent.com/')
# raw_url = re.sub(r'/tree/([^/]+)/', r'/\1/', raw_url)
# raw_url = raw_url.rstrip('/') + '/SKILL.md'
#
# print(f'GitHub URL: {github_url}')
# print(f'Raw URL: {raw_url}')
# "</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ✏️ <b>write_file</b> — Writing: <code>/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager_fixed.py</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/install_emergency_manager_fixed.py",
#   "content": "#!/usr/bin/env python3\n\"\"\"\nInstall emergency-manager skill using SkillsMP API (FIXED).\n\"\"\"\nimport requests\nimport re\nimport os\nfrom pathlib import Path\nfrom dotenv import load_dotenv\n\n# Load API key from Sage .env\nsage_env = Path(\"/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/.env\")\nload_dotenv(sage_env, override=True)\n\nAPI_KEY = os.environ.get(\"SKILLSMP_API_KEY\")\nif not API_KEY:\n    print(\"ERROR: SKILLSMP_API_KEY not found\")\n    exit(1)\n\nskill_name = \"emergency-manager\"\n\n# Step 1: Check if already installed\nprint(f\"Step 1: Checking if '{skill_name}' is already installed...\")\nskill_dir = Path.home() / \".deepagents\" / \"agent\" / \"skills\" / skill_name\nif (skill_dir / \"SKILL.md\").exists():\n    print(f\"✓ Skill '{skill_name}' is already installed at {skill_dir}\")\n    exit(0)\nelse:\n    print(f\"  Skill not yet installed. Proceeding with installation.\")\n\n# Step 2: Search SkillsMP for the skill\nprint(f\"\\nStep 2: Searching SkillsMP for '{skill_name}'...\")\nsearch_url = \"https://skillsmp.com/api/v1/skills/search\"\nheaders = {\"Authorization\": f\"Bearer {API_KEY}\"}\n\nresp = requests.get(search_url, params={\"q\": skill_name}, headers=headers, timeout=15)\nresp.raise_for_status()\ndata = resp.json()\n\nif not data.get(\"success\"):\n    print(f\"ERROR: API returned unsuccessful: {data}\")\n    exit(1)\n\nskills = data.get(\"data\", {}).get(\"skills\", [])\nmatching_skill = None\n\nfor skill in skills:\n    if skill.get(\"name\") == skill_name:\n        matching_skill = skill\n        break\n\nif not matching_skill:\n    print(f\"ERROR: Could not find skill '{skill_name}' in search results\")\n    print(f\"  Found {len(skills)} skills:\")\n    for s in skills[:5]:\n        print(f\"    - {s.get('name')}\")\n    exit(1)\n\ngithub_url = matching_skill.get(\"githubUrl\")\nprint(f\"  ✓ Found skill:\")\nprint(f\"    Author: {matching_skill.get('author')}\")\nprint(f\"    Stars: {matching_skill.get('stars')}\")\nprint(f\"    GitHub URL: {github_url}\")\n\n# Step 3: Fetch SKILL.md from GitHub\nprint(f\"\\nStep 3: Fetching SKILL.md from GitHub...\")\n\n# Convert github URL to raw URL (FIXED regex to preserve branch name)\n# https://github.com/Author/Repo/tree/branch/path -&gt; https://raw.githubusercontent.com/Author/Repo/branch/path/SKILL.md\nraw_url = github_url\nraw_url = raw_url.replace(\"https://github.com/\", \"https://raw.githubusercontent.com/\")\nraw_url = re.sub(r'/tree/([^/]+)/', r'/\\1/', raw_url)\nraw_url = raw_url.rstrip('/') + \"/SKILL.md\"\n\nprint(f\"  Raw URL: {raw_url}\")\n\ntry:\n    resp = requests.get(raw_url, timeout=15)\n    resp.raise_for_status()\n    skill_content = resp.text\n\n    # Preview first 200 chars\n    print(f\"  Preview: {skill_content[:200]}...\")\nexcept Exception as e:\n    print(f\"ERROR: Failed to fetch SKILL.md: {e}\")\n    exit(1)\n\n# Step 4: Write skill to disk\nprint(f\"\\nStep 4: Writing skill to disk...\")\nname_match = re.search(r'^name:\\s*(\\S+)', skill_content, re.MULTILINE)\nextracted_name = name_match.group(1) if name_match else \"unknown-skill\"\n\nif extracted_name != skill_name:\n    print(f\"WARNING: Extracted name '{extracted_name}' differs from expected '{skill_name}'\")\n    print(f\"  Using extracted name: {extracted_name}\")\n    skill_name = extracted_name\n\nskill_dir = Path.home() / \".deepagents\" / \"agent\" / \"skills\" / skill_name\nskill_dir.mkdir(parents=True, exist_ok=True)\n\nskill_file = skill_dir / \"SKILL.md\"\nskill_file.write_text(skill_content)\n\nprint(f\"  ✓ Installed skill '{skill_name}' to {skill_dir}\")\n\n# Step 5: Confirm installation\nprint(f\"\\nStep 5: Confirming installation...\")\ninstalled_path = skill_dir / \"SKILL.md\"\nsize = installed_path.stat().st_size\nprint(f\"  ✓ Confirmed: {installed_path} ({size} bytes)\")\n\nprint(f\"\\n✓✓✓ Successfully installed '{skill_name}' skill!\")\n"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_ &amp;&amp; /opt/conda/bin/python install_emergency_manager_fixed.py</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>ls -lh /home/jovyan/.deepagents/agent/skills/emergency-manager/</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>ls -lh /home/jovyan/.deepagents/agent/skills/emergency-manager/</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md",
#   "limit": 30
# }</pre>
#     </div>
#   </details>
# </div>
# ## Installation Complete!
#
# I've successfully installed the **emergency-manager** skill from the SkillsMP marketplace.
#
# **Installation Details:**
# - **Skill name** : emergency-manager
# - **Author** : theNeoAI (lucas_hsueh@hotmail.com)
# - **Stars** : 33
# - **Version** : 1.0.0
# - **License** : MIT
# - **Installation path** : `/home/jovyan/.deepagents/agent/skills/emergency-manager/`
# - **File size** : 10,197 bytes
#
# **Skill Summary:**
# The emergency-manager skill provides expert-level emergency management capabilities covering:
# - Disaster preparedness and planning
# - Response coordination (ICS/NIMS)
# - Hazard mitigation and risk assessment
# - Crisis communication and public information
# - Evacuation operations
# - Disaster recovery and long-term resilience
#
# The skill is now available for use in your agent. You can invoke it whenever you need emergency management expertise for tasks like developing emergency plans, coordinating multi-agency response, managing evacuation operations, or leading disaster recovery efforts.

# %%
# %%ask
# We have a major hurricane approaching in Florida next week.
# How do we coordinate the response? Please show a timeline plan.
# Out:
# I'll help you coordinate the hurricane response. Let me first consult the emergency-manager skill to apply the proper emergency management framework.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md",
#   "offset": 100,
#   "limit": 150
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/references/7-workflow.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/references/7-workflow.md"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📁 <b>ls</b> — <code>{"path": "/home/jovyan/.deepagents/agent/skills/emergency-manager"}</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "path": "/home/jovyan/.deepagents/agent/skills/emergency-manager"
# }</pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   📖 <b>read_file</b> — Reading: <code>/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>{
#   "file_path": "/home/jovyan/.deepagents/agent/skills/emergency-manager/SKILL.md",
#   "limit": 100,
#   "offset": 250
# }</pre>
#     </div>
#   </details>
# </div>
# Now I'll create a comprehensive hurricane response coordination timeline plan based on emergency management best practices.
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_ &amp;&amp; /opt/conda/bin/python -c "
# import matplotlib.pyplot as plt
# import matplotlib.dates as mdates
# from datetime import datetime, timedelta
#
# # Set up the plot with large size as required
# fig, ax = plt.subplots(figsize=(16, 10), dpi=150)
#
# # Define timeline phases and tasks
# phases = [
#     {'name': 'PRE-LANDFALL PREPARATION', 'days': -5, 'color': '#FFD700', 'tasks': [
#         ('Day -5: Watch Declaration', 'Activate EOC Level III, brief stakeholders'),
#         ('Day -4: Warning Declaration', 'Upgrade to Level II, pre-position resources'),
#         ('Day -3: Evacuation Order', 'Zone A evacuation, shelters open'),
#         ('Day -2: Complete Evacuation', 'Zone B/C evacuation, finalize prep'),
#         ('Day -1: Final Preparations', 'Secure infrastructure, brace for impact'),
#     ]},
#     {'name': 'IMPACT PHASE', 'days': 0, 'color': '#FF6B6B', 'tasks': [
#         ('Landfall - 6 hours', 'Hunker down, last-minute warnings'),
#         ('Landfall', 'Life safety priority only, suspend non-essential'),
#         ('Landfall + 6 hours', 'Wait for conditions to improve'),
#         ('Landfall + 12 hours', 'Begin rapid damage assessments'),
#     ]},
#     {'name': 'IMMEDIATE RESPONSE', 'days': 1, 'color': '#FFA500', 'tasks': [
#         ('Day 1 Morning', 'Search and rescue begins, road clearance'),
#         ('Day 1 Afternoon', 'Infrastructure assessment, critical repairs'),
#         ('Day 1 Evening', 'Initial damage report, prioritize areas'),
#     ]},
#     {'name': 'SHORT-TERM RECOVERY', 'days': 3, 'color': '#4ECDC4', 'tasks': [
#         ('Day 2-3', 'Restore power/water, debris removal'),
#         ('Day 4-5', 'Re-entry authorization, supply distribution'),
#         ('Day 6-7', 'Business recovery support, temp housing'),
#     ]},
#     {'name': 'LONG-TERM RECOVERY', 'days': 14, 'color': '#95E1D3', 'tasks': [
#         ('Week 2-3', 'Major infrastructure repair'),
#         ('Week 4-6', 'Housing assistance, FEMA coordination'),
#         ('Week 7+', 'Mitigation planning, rebuild resilient'),
#     ]},
# ]
#
# # Create horizontal timeline bars
# y_pos = 0
# phase_labels = []
# y_positions = []
#
# for phase in phases:
#     # Calculate start and end positions (each day = 1 unit width)
#     if phase['days'] &lt;= 0:
#         start_x = phase['days']
#         end_x = max(1, phase['days'] + (len(phase['tasks']) / 3))
#     else:
#         start_x = phase['days']
#         end_x = start_x + (len(phase['tasks']) / 2)
#
#     # Draw the phase bar
#     ax.barh(y_pos, end_x - start_x, left=start_x, height=0.6,
#             color=phase['color'], alpha=0.7, edgecolor='black', linewidth=1.5)
#
#     # Add phase label
#     ax.text(-4.8, y_pos, phase['name'], ha='right', va='center',
#             fontsize=11, fontweight='bold')
#
#     phase_labels.append(phase['name'])
#     y_positions.append(y_pos)
#     y_pos += 1
#
# # Customize the chart
# ax.set_xlabel('Days Relative to Landfall', fontsize=12, fontweight='bold')
# ax.set_title('Florida Hurricane Response Coordination Timeline',
#              fontsize=16, fontweight='bold', pad=20)
# ax.set_yticks(y_positions)
# ax.set_yticklabels([])
#
# # Set x-axis to show days around landfall
# ax.set_xlim(-5, 21)
# ax.axvline(x=0, color='red', linestyle='--', linewidth=2, alpha=0.7, label='Landfall')
# ax.grid(axis='x', alpha=0.3)
#
# # Add x-axis ticks
# xticks = list(range(-5, 22, 3))
# ax.set_xticks(xticks)
# ax.set_xticklabels([f'Day {d}' if d != 0 else 'Landfall' for d in xticks], rotation=45)
#
# # Add legend
# legend_elements = [
#     plt.Rectangle((0,0),1,1, facecolor='#FFD700', alpha=0.7, edgecolor='black', label='Pre-Landfall Prep'),
#     plt.Rectangle((0,0),1,1, facecolor='#FF6B6B', alpha=0.7, edgecolor='black', label='Impact Phase'),
#     plt.Rectangle((0,0),1,1, facecolor='#FFA500', alpha=0.7, edgecolor='black', label='Immediate Response'),
#     plt.Rectangle((0,0),1,1, facecolor='#4ECDC4', alpha=0.7, edgecolor='black', label='Short-Term Recovery'),
#     plt.Rectangle((0,0),1,1, facecolor='#95E1D3', alpha=0.7, edgecolor='black', label='Long-Term Recovery'),
# ]
# ax.legend(handles=legend_elements, loc='upper right', fontsize=10)
#
# # Add priority annotation
# ax.text(-5, 5.5, 'PRIORITY HIERARCHY: LIFE SAFETY → STABILIZATION → PROTECTION → RECOVERY',
#         fontsize=11, fontweight='bold', style='italic',
#         bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
#
# plt.tight_layout()
# plt.savefig('/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_timeline.png',
#             dpi=150, bbox_inches='tight')
# print('Timeline chart created successfully')
# "
# </pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_ &amp;&amp; /opt/conda/bin/python -c "
# import pandas as pd
#
# # Create a comprehensive response coordination table
# data = []
#
# # PRE-LANDFALL PHASE
# pre_landfall = [
#     ('Day -5: Watch Declaration', 'Pre-Landfall', 'Activate EOC Level III (Monitoring)', 'Emergency Management'),
#     ('Day -5: Watch Declaration', 'Pre-Landfall', 'Brief Governor, State Agencies, County EM Directors', 'State EOC'),
#     ('Day -5: Watch Declaration', 'Pre-Landfall', 'Activate State Emergency Response Team (SERT)', 'FDEM'),
#     ('Day -5: Watch Declaration', 'Pre-Landfall', 'Update public information channels', 'PIO'),
#     ('Day -4: Warning Declaration', 'Pre-Landfall', 'Upgrade to EOC Level II (Partial Activation)', 'Emergency Management'),
#     ('Day -4: Warning Declaration', 'Pre-Landfall', 'Pre-position search and rescue teams', 'FLTF-1/2'),
#     ('Day -4: Warning Declaration', 'Pre-Landfall', 'Stage emergency supplies (water, MREs, tarps)', 'Logistics Section'),
#     ('Day -4: Warning Declaration', 'Pre-Landfall', 'Alert mutual aid partners (EMAC)', 'State EOC'),
#     ('Day -3: Evacuation Order', 'Pre-Landfall', 'Issue mandatory evacuation: Zone A (coastal)', 'County EM'),
#     ('Day -3: Evacuation Order', 'Pre-Landfall', 'Open general population shelters', 'Red Cross / County'),
#     ('Day -3: Evacuation Order', 'Pre-Landfall', 'Activate special needs shelter registry', 'Health Department'),
#     ('Day -3: Evacuation Order', 'Pre-Landfall', 'Begin contraflow lane reversals on I-75/I-95', 'FDOT'),
#     ('Day -2: Complete Evacuation', 'Pre-Landfall', 'Expand evacuation to Zone B/C', 'County EM'),
#     ('Day -2: Complete Evacuation', 'Pre-Landfall', 'Finalize shelter staffing and supplies', 'Shelter Manager'),
#     ('Day -2: Complete Evacuation', 'Pre-Landfall', 'Coordinate pet sheltering operations', 'Agriculture Dept'),
#     ('Day -2: Complete Evacuation', 'Pre-Landfall', 'Secure critical infrastructure', 'Utility Companies'),
#     ('Day -1: Final Preparations', 'Pre-Landfall', 'Upgrade to EOC Level I (Full Activation)', 'State EOC'),
#     ('Day -1: Final Preparations', 'Pre-Landfall', 'Halt all non-emergency services', 'All Agencies'),
#     ('Day -1: Final Preparations', 'Pre-Landfall', 'Final public briefings, evacuation deadline', 'Governor / PIO'),
#     ('Day -1: Final Preparations', 'Pre-Landfall', 'Pre-position damage assessment teams', 'FEMA / State'),
# ]
#
# data.extend(pre_landfall)
#
# # IMPACT PHASE
# impact = [
#     ('Landfall - 6 hours', 'Impact', 'All response teams hunker down in safe locations', 'All Personnel'),
#     ('Landfall - 6 hours', 'Impact', 'Final warnings: stay indoors, away from windows', 'PIO / Media'),
#     ('Landfall - 6 hours', 'Impact', 'Emergency services suspended except life-critical', '911 Centers'),
#     ('Landfall - 6 hours', 'Impact', 'Monitor water levels, storm surge sensors', 'NWS / USGS'),
#     ('Landfall', 'Impact', 'LIFE SAFETY ONLY - sustain in place', 'All Personnel'),
#     ('Landfall', 'Impact', 'Track 911 calls, prioritize imminent threats', 'Emergency Comm'),
#     ('Landfall', 'Impact', 'Maintain situational awareness at EOC', 'Planning Section'),
#     ('Landfall + 6 hours', 'Impact', 'Continue shelter-in-place for public', 'All Agencies'),
#     ('Landfall + 6 hours', 'Impact', 'Begin weather condition assessments', 'NWS / Field Teams'),
#     ('Landfall + 6 hours', 'Impact', 'Prepare for immediate SAR deployment', 'FLTF-1/2'),
#     ('Landfall + 12 hours', 'Impact', 'Deploy urban search and rescue where safe', 'FLTF-1/2'),
#     ('Landfall + 12 hours', 'Impact', 'Begin aerial reconnaissance (helicopters/drones)', 'NG / FHP'),
#     ('Landfall + 12 hours', 'Impact', 'Initial bridge/road structural assessments', 'FDOT / Engineers'),
# ]
#
# data.extend(impact)
#
# # IMMEDIATE RESPONSE PHASE
# immediate = [
#     ('Day 1 Morning', 'Immediate Response', 'Full-scale search and rescue operations', 'FLTF-1/2, Local Fire'),
#     ('Day 1 Morning', 'Immediate Response', 'Clear priority routes for emergency access', 'FDOT, Public Works'),
#     ('Day 1 Morning', 'Immediate Response', 'Restore critical communications infrastructure', 'FCC, Carriers'),
#     ('Day 1 Morning', 'Immediate Response', 'Medical triage and transport to hospitals', 'EMS, Hospitals'),
#     ('Day 1 Afternoon', 'Immediate Response', 'Power grid damage assessment', 'FPL, Duke Energy'),
#     ('Day 1 Afternoon', 'Immediate Response', 'Water/wastewater system evaluation', 'Utilities, EPA'),
#     ('Day 1 Afternoon', 'Immediate Response', 'Begin preliminary damage assessment (PDA)', 'FEMA / State Teams'),
#     ('Day 1 Evening', 'Immediate Response', 'Prioritize areas for next-day operations', 'Planning Section'),
#     ('Day 1 Evening', 'Immediate Response', 'Public update on conditions and re-entry', 'Governor / PIO'),
#     ('Day 1 Evening', 'Immediate Response', 'Request federal assistance (if needed)', 'Governor to President'),
# ]
#
# data.extend(immediate)
#
# # SHORT-TERM RECOVERY PHASE
# short_term = [
#     ('Day 2-3', 'Short-Term Recovery', 'Restore power to critical facilities first', 'Utility Companies'),
#     ('Day 2-3', 'Short-Term Recovery', 'Water system repairs, boil water advisories', 'Water Management'),
#     ('Day 2-3', 'Short-Term Recovery', 'Debris removal from roadways', 'USACE, FDOT, Counties'),
#     ('Day 2-3', 'Short-Term Recovery', 'Distribution points: water, food, ice, tarps', 'Logistics, National Guard'),
#     ('Day 4-5', 'Short-Term Recovery', 'Authorize re-entry for evacuated zones', 'County EM'),
#     ('Day 4-5', 'Short-Term Recovery', 'FEMA Disaster Recovery Centers (DRCs) open', 'FEMA'),
#     ('Day 4-5', 'Short-Term Recovery', 'Individual Assistance registration begins', 'FEMA / State'),
#     ('Day 4-5', 'Short-Term Recovery', 'Infrastructure inspection: bridges, dams, levees', 'USACE, FDOT'),
#     ('Day 6-7', 'Short-Term Recovery', 'Business damage assessment outreach', 'SBA, Economic Dev'),
#     ('Day 6-7', 'Short-Term Recovery', 'Temporary housing units (if needed)', 'FEMA, HUD'),
#     ('Day 6-7', 'Short-Term Recovery', 'Transition from response to recovery focus', 'State EOC'),
# ]
#
# data.extend(short_term)
#
# # LONG-TERM RECOVERY PHASE
# long_term = [
#     ('Week 2-3', 'Long-Term Recovery', 'Major infrastructure repair projects', 'USACE, FDOT'),
#     ('Week 2-3', 'Long-Term Recovery', 'Schools and public facilities restoration', 'School Districts'),
#     ('Week 2-3', 'Long-Term Recovery', 'Environmental cleanup and monitoring', 'DEP, EPA'),
#     ('Week 4-6', 'Long-Term Recovery', 'Public Assistance (PA) program implementation', 'FEMA'),
#     ('Week 4-6', 'Long-Term Recovery', 'Housing rehabilitation and reconstruction', 'HUD, SBA'),
#     ('Week 4-6', 'Long-Term Recovery', 'Economic recovery grants and loans', 'SBA, EDA'),
#     ('Week 7+', 'Long-Term Recovery', 'Hazard mitigation project development', 'FEMA HMGP'),
#     ('Week 7+', 'Long-Term Recovery', 'Update comprehensive emergency plans', 'All EM Agencies'),
#     ('Week 7+', 'Long-Term Recovery', 'After-action report and improvement plan', 'State / FEMA'),
#     ('Week 7+', 'Long-Term Recovery', 'Community resilience building initiatives', 'Long-Term Recovery'),
# ]
#
# data.extend(long_term)
#
# # Create DataFrame
# df = pd.DataFrame(data, columns=['Timeline', 'Phase', 'Action', 'Lead Agency'])
#
# # Save to CSV
# df.to_csv('/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/hurricane_response_plan.csv',
#           index=False)
#
# print(f'Created response plan with {len(df)} coordinated actions')
# print('File saved successfully')
# "
# <
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_ &amp;&amp; /opt/conda/bin/python -c "
# import matplotlib.pyplot as plt
# from matplotlib.patches import FancyBboxPatch, FancyArrowPatch
# import matplotlib.patches as mpatches
#
# # Create the ICS organization chart
# fig, ax = plt.subplots(figsize=(16, 12), dpi=150)
#
# # Set up the plot
# ax.set_xlim(0, 10)
# ax.set_ylim(0, 10)
# ax.axis('off')
#
# # Color scheme
# colors = {
#     'IC': '#FF6B6B',
#     'OPS': '#4ECDC4',
#     'PLN': '#45B7D1',
#     'LOG': '#96CEB4',
#     'FIN': '#FFEAA7',
#     'LIAISON': '#DDA0DD',
#     'SAFETY': '#F39C12',
#     'PIO': '#E74C3C'
# }
#
# # Function to draw a box
# def draw_box(x, y, width, height, text, color, fontsize=10):
#     box = FancyBboxPatch((x - width/2, y - height/2), width, height,
#                          boxstyle='round,pad=0.1',
#                          edgecolor='black', facecolor=color, linewidth=2)
#     ax.add_patch(box)
#     ax.text(x, y, text, ha='center', va='center',
#             fontsize=fontsize, fontweight='bold', wrap=True)
#
# # Function to draw an arrow
# def draw_arrow(x1, y1, x2, y2):
#     arrow = FancyArrowPatch((x1, y1), (x2, y2),
#                            arrowstyle='-&gt;', mutation_scale=20,
#                            linewidth=2, color='black')
#     ax.add_patch(arrow)
#
# # Draw Incident Commander at top
# draw_box(5, 9, 3.5, 0.8, 'INCIDENT COMMANDER\\n(State / County EOC Director)', colors['IC'], 11)
#
# # Draw General Staff positions
# gs_y = 7.2
# draw_box(1.5, gs_y, 2.2, 0.7, 'OPERATIONS\\n(Response Coord.)', colors['OPS'], 10)
# draw_box(3.8, gs_y, 2.2, 0.7, 'PLANNING\\n(Intel &amp; Situation)', colors['PLN'], 10)
# draw_box(6.1, gs_y, 2.2, 0.7, 'LOGISTICS\\n(Resources &amp; Support)', colors['LOG'], 10)
# draw_box(8.4, gs_y, 2.2, 0.7, 'FINANCE/ADMIN\\n(Costs &amp; Procurement)', colors['FIN'], 10)
#
# # Draw Command Staff positions
# cs_y = 7.2
# draw_box(5, 6.0, 2.5, 0.6, 'PUBLIC INFORMATION\\n(PIO)', colors['PIO'], 9)
# draw_box(2.5, 6.0, 2.2, 0.6, 'LIAISON OFFICER\\n(Agency Coord.)', colors['LIAISON'], 9)
# draw_box(7.5, 6.0, 2.2, 0.6, 'SAFETY OFFICER\\n(Risk Mgmt)', colors['SAFETY'], 9)
#
# # Arrows from IC to General Staff
# draw_arrow(5, 8.6, 1.5, 7.55)
# draw_arrow(5, 8.6, 3.8, 7.55)
# draw_arrow(5, 8.6, 6.1, 7.55)
# draw_arrow(5, 8.6, 8.4, 7.55)
#
# # Arrows from IC to Command Staff
# draw_arrow(5, 8.6, 5, 6.3)
# draw_arrow(5, 8.6, 2.5, 6.3)
# draw_arrow(5, 8.6, 7.5, 6.3)
#
# # Operations Section details
# ops_y = 5.5
# draw_box(0.8, ops_y, 1.5, 0.5, 'Branches:\\n• SAR\\n• Evacuation\\n• Medical\\n• Fire', colors['OPS'], 8)
# draw_box(2.5, ops_y, 1.5, 0.5, 'Divisions:\\n• Geographic\\n• Functional', colors['OPS'], 8)
# draw_box(4.2, ops_y, 1.5, 0.5, 'Groups:\\n• Rescue\\n• Support', colors['OPS'], 8)
#
# draw_arrow(1.5, 6.85, 1.5, 5.75)
# draw_arrow(1.5, 6.85, 2.5, 5.75)
# draw_arrow(1.5, 6.85, 4.2, 5.75)
#
# # Planning Section details
# pln_y = 5.5
# draw_box(3.8, pln_y, 2.2, 0.5, 'Planning Units:\\n• Situation\\n• Resources\\n• Documentation\\n• Demobilization', colors['PLN'], 8)
#
# draw_arrow(3.8, 6.85, 3.8, 5.75)
#
# # Logistics Section details
# log_y = 5.5
# draw_box(6.1, log_y, 2.2, 0.5, 'Logistics Units:\\n• Supply\\n• Facilities\\n• Ground Support\\n• Communications\\n• Medical', colors['LOG'], 8)
#
# draw_arrow(6.1, 6.85, 6.1, 5.75)
#
# # Finance Section details
# fin_y = 5.5
# draw_box(8.4, fin_y, 2.2, 0.5, 'Finance Units:\\n• Procurement\\n• Compensation\\n• Claims\\n• Cost Tracking', colors['FIN'], 8)
#
# draw_arrow(8.4, 6.85, 8.4, 5.75)
#
# # Key Agencies section
# key_agencies = [
#     'FL State Emergency Management (FDEM)',
#     'Florida National Guard',
#     'Florida Highway Patrol (FHP)',
#     'Florida Dept of Transportation (FDOT)',
#     'Florida Health Department',
#     'Florida Power &amp; Light / Duke Energy',
#     'American Red Cross',
#     'FEMA Region IV',
#     'US Army Corps of Engineers (USACE)',
#     'Urban Search &amp; Rescue (FLTF-1/2)',
# ]
#
# agencies_y = 4.0
# ax.text(5, agencies_y + 0.8, 'KEY COORDINATING AGENCIES',
#         ha='center', fontsize=12, fontweight='bold')
#
# for i, agency in enumerate(key_agencies):
#     col = i % 2
#     row = i // 2
#     x = 2.5 + col * 4
#     y = agencies_y - row * 0.35
#     ax.text(x, y, f'• {agency}', ha='left', va='center', fontsize=9)
#
# # Title
# ax.set_title('HURRICANE RESPONSE INCIDENT COMMAND SYSTEM STRUCTURE',
#              fontsize=14, fontweight='bold', pad=10)
#
# # Add legend
# legend_y = 1.0
# legend_items = [
#     ('Incident Commander', colors['IC']),
#     ('Operations (Does the work)', colors['OPS']),
#     ('Planning (Plans the work)', colors['PLN']),
#     ('Logistics (Supports the work)', colors['LOG']),
#     ('Finance/Admin (Pays for the work)', colors['FIN']),
#     ('Command Staff', colors['PIO']),
# ]
#
# for i, (label, color) in enumerate(legend_items):
#     x = 0.5 + (i % 3) * 3
#     y = legend_y - (i // 3) * 0.4
#     ax.add_patch(plt.Rectangle((x, y - 0.15), 0.3, 0.3,
#                                facecolor=color, edgecolor='black'))
#     ax.text(x + 0.4, y, label, va='center', fontsize=8)
#
# plt.tight_layout()
# plt.savefig('/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/ics_organization.png',
#             dpi=150, bbox_inches='tight')
# print('ICS organization chart created successfully')
# "
# </pre>
#     </div>
#   </details>
# </div>
# <div style="background:#f5f7ff; border-left:3px solid #4a7fd4;
#             padding:5px 10px; margin:3px 0 12px 0; font-size:0.85em;">
#   ⚙️ <b>execute</b> — Executing: <code>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_...</code>
#   <details>
#     <summary style="cursor:pointer; color:#888; font-size:0.9em;">details</summary>
#     <div style="margin-top:4px; font-family:monospace; font-size:0.9em;">
#       <pre style='margin:0'>cd /home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_ &amp;&amp; /opt/conda/bin/python -c "
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Create resource allocation priority chart
# fig, ax = plt.subplots(figsize=(14, 10), dpi=150)
#
# # Define resource categories and their priorities
# categories = [
#     'Search &amp; Rescue',
#     'Medical Response',
#     'Emergency Communications',
#     'Power Restoration',
#     'Water/Wastewater',
#     'Shelter Operations',
#     'Food/Water Distribution',
#     'Road Clearance',
#     'Debris Removal',
#     'Damage Assessment',
#     'Public Information',
#     'Security/Law Enforcement',
# ]
#
# phases = ['Pre-Landfall', 'Impact', 'Day 1', 'Day 2-3', 'Day 4-7', 'Week 2+']
#
# # Priority matrix (1=low, 2=medium, 3=high, 4=critical)
# priority_data = {
#     'Search &amp; Rescue': [1, 4, 4, 4, 3, 2],
#     'Medical Response': [2, 4, 4, 4, 3, 2],
#     'Emergency Communications': [3, 4, 4, 4, 3, 2],
#     'Power Restoration': [3, 1, 4, 4, 4, 3],
#     'Water/Wastewater': [3, 1, 3, 4, 4, 3],
#     'Shelter Operations': [4, 4, 4, 4, 3, 1],
#     'Food/Water Distribution': [3, 2, 3, 4, 4, 2],
#     'Road Clearance': [3, 1, 4, 4, 3, 2],
#     'Debris Removal': [1, 1, 2, 3, 4, 3],
#     'Damage Assessment': [2, 2, 3, 4, 3, 2],
#     'Public Information': [4, 4, 4, 4, 3, 2],
#     'Security/Law Enforcement': [3, 3, 4, 4, 3, 2],
# }
#
# # Create heatmap
# data = np.array([priority_data[cat] for cat in categories])
#
# im = ax.imshow(data, cmap='RdYlGn', aspect='auto', vmin=1, vmax=4)
#
# # Set ticks and labels
# ax.set_xticks(np.arange(len(phases)))
# ax.set_yticks(np.arange(len(categories)))
# ax.set_xticklabels(phases, fontsize=10, fontweight='bold')
# ax.set_yticklabels(categories, fontsize=10)
#
# # Rotate x-axis labels
# plt.setp(ax.get_xticklabels(), rotation=45, ha='right')
#
# # Add text annotations
# for i in range(len(categories)):
#     for j in range(len(phases)):
#         text = ax.text(j, i, priority_data[categories[i]][j],
#                       ha='center', va='center', color='black',
#                       fontsize=11, fontweight='bold')
#
# # Add colorbar
# cbar = plt.colorbar(im, ax=ax, shrink=0.8)
# cbar.set_ticks([1, 2, 3, 4])
# cbar.set_ticklabels(['Low', 'Medium', 'High', 'Critical'], fontsize=10)
# cbar.set_label('Priority Level', fontsize=11, fontweight='bold')
#
# # Labels and title
# ax.set_xlabel('Response Phase', fontsize=12, fontweight='bold')
# ax.set_ylabel('Resource Category', fontsize=12, fontweight='bold')
# ax.set_title('Hurricane Response Resource Allocation Priority Matrix',
#              fontsize=15, fontweight='bold', pad=20)
#
# # Add priority explanation
# explanation = '''
# PRIORITY LEVELS:
# 1 = LOW      - Not active or minimal need
# 2 = MEDIUM   - Monitor and prepare
# 3 = HIGH     - Active response required
# 4 = CRITICAL - Maximum priority, immediate action
# '''
#
# ax.text(0.5, -0.15, explanation, transform=ax.transAxes,
#         fontsize=9, ha='left', va='top',
#         bbox=dict(boxstyle='round', facecolor='lightyellow', alpha=0.8))
#
# plt.tight_layout()
# plt.savefig('/home/jovyan/work/_User-Persistent-Storage_CephBlock_/Sage/_skills_manage_sage_/priority_matrix.png',
#             dpi=150, bbox_inches='tight')
# print('Priority matrix created successfully')
# "
# </pre>
#     </div>
#   </details>
# </div>
# # Florida Hurricane Response Coordination Plan
#
# Based on the emergency management framework and NIMS/ICS best practices, here is a comprehensive timeline and coordination plan for the approaching hurricane.
#
# ---
#
# ## Response Timeline Overview
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Hurricane Response Timeline</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# The response follows the **Emergency Management Priority Hierarchy** :
#
# 1. **LIFE SAFETY** (Immediate) — Protect human life above all else
# 2. **INCIDENT STABILIZATION** (Hours to days) — Control the situation, prevent escalation
# 3. **PROPERTY AND ENVIRONMENTAL PROTECTION** (Days) — Minimize damage to property and environment
# 4. **RESTORATION OF SERVICES** (Days to weeks) — Return community to normal functioning
# 5. **RECOVERY AND MITIGATION** (Weeks to years) — Rebuild stronger, reduce future risk
#
# ---
#
# ## Incident Command System Structure
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>ICS Organization Chart</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# The response is coordinated through a unified ICS structure with:
#
# - **Incident Commander** : State/County EOC Director (ultimate authority)
# - **Operations Section** : Executes the response (SAR, evacuation, medical, fire)
# - **Planning Section** : Gathers intelligence, develops action plans
# - **Logistics Section** : Provides resources, facilities, communications, support
# - **Finance/Admin Section** : Tracks costs, manages procurement and compensation
# - **Command Staff** : Public Information, Liaison, and Safety Officers
#
# ---
#
# ## Detailed Coordination Actions by Phase
#
# ### Pre-Landfall Preparation (Days -5 to -1)
#
# | Timeline | Action | Lead Agency |
# |----------|--------|-------------|
# | **Day -5** : Watch Declaration | Activate EOC Level III (Monitoring) | Emergency Management |
# | **Day -5** : Watch Declaration | Brief Governor, State Agencies, County EM Directors | State EOC |
# | **Day -5** : Watch Declaration | Activate State Emergency Response Team (SERT) | FDEM |
# | **Day -5** : Watch Declaration | Update public information channels | PIO |
# | **Day -4** : Warning Declaration | Upgrade to EOC Level II (Partial Activation) | Emergency Management |
# | **Day -4** : Warning Declaration | Pre-position search and rescue teams | FLTF-1/2 |
# | **Day -4** : Warning Declaration | Stage emergency supplies (water, MREs, tarps) | Logistics Section |
# | **Day -4** : Warning Declaration | Alert mutual aid partners (EMAC) | State EOC |
# | **Day -3** : Evacuation Order | Issue mandatory evacuation: Zone A (coastal) | County EM |
# | **Day -3** : Evacuation Order | Open general population shelters | Red Cross / County |
# | **Day -3** : Evacuation Order | Activate special needs shelter registry | Health Department |
# | **Day -3** : Evacuation Order | Begin contraflow lane reversals on I-75/I-95 | FDOT |
# | **Day -2** : Complete Evacuation | Expand evacuation to Zone B/C | County EM |
# | **Day -2** : Complete Evacuation | Finalize shelter staffing and supplies | Shelter Manager |
# | **Day -2** : Complete Evacuation | Coordinate pet sheltering operations | Agriculture Dept |
# | **Day -2** : Complete Evacuation | Secure critical infrastructure | Utility Companies |
# | **Day -1** : Final Preparations | Upgrade to EOC Level I (Full Activation) | State EOC |
# | **Day -1** : Final Preparations | Halt all non-emergency services | All Agencies |
# | **Day -1** : Final Preparations | Final public briefings, evacuation deadline | Governor / PIO |
# | **Day -1** : Final Preparations | Pre-position damage assessment teams | FEMA / State |
#
# ### Impact Phase (Landfall ±12 hours)
#
# | Timeline | Action | Lead Agency |
# |----------|--------|-------------|
# | **Landfall - 6 hours** | All response teams hunker down in safe locations | All Personnel |
# | **Landfall - 6 hours** | Final warnings: stay indoors, away from windows | PIO / Media |
# | **Landfall - 6 hours** | Emergency services suspended except life-critical | 911 Centers |
# | **Landfall - 6 hours** | Monitor water levels, storm surge sensors | NWS / USGS |
# | **Landfall** | LIFE SAFETY ONLY - sustain in place | All Personnel |
# | **Landfall** | Track 911 calls, prioritize imminent threats | Emergency Comm |
# | **Landfall** | Maintain situational awareness at EOC | Planning Section |
# | **Landfall + 6 hours** | Continue shelter-in-place for public | All Agencies |
# | **Landfall + 6 hours** | Begin weather condition assessments | NWS / Field Teams |
# | **Landfall + 6 hours** | Prepare for immediate SAR deployment | FLTF-1/2 |
# | **Landfall + 12 hours** | Deploy urban search and rescue where safe | FLTF-1/2 |
# | **Landfall + 12 hours** | Begin aerial reconnaissance (helicopters/drones) | NG / FHP |
# | **Landfall + 12 hours** | Initial bridge/road structural assessments | FDOT / Engineers |
#
# ### Immediate Response (Day 1)
#
# | Timeline | Action | Lead Agency |
# |----------|--------|-------------|
# | **Day 1 Morning** | Full-scale search and rescue operations | FLTF-1/2, Local Fire |
# | **Day 1 Morning** | Clear priority routes for emergency access | FDOT, Public Works |
# | **Day 1 Morning** | Restore critical communications infrastructure | FCC, Carriers |
# | **Day 1 Morning** | Medical triage and transport to hospitals | EMS, Hospitals |
# | **Day 1 Afternoon** | Power grid damage assessment | FPL, Duke Energy |
# | **Day 1 Afternoon** | Water/wastewater system evaluation | Utilities, EPA |
# | **Day 1 Afternoon** | Begin preliminary damage assessment (PDA) | FEMA / State Teams |
# | **Day 1 Evening** | Prioritize areas for next-day operations | Planning Section |
# | **Day 1 Evening** | Public update on conditions and re-entry | Governor / PIO |
# | **Day 1 Evening** | Request federal assistance (if needed) | Governor to President |
#
# ### Short-Term Recovery (Days 2-7)
#
# | Timeline | Action | Lead Agency |
# |----------|--------|-------------|
# | **Day 2-3** | Restore power to critical facilities first | Utility Companies |
# | **Day 2-3** | Water system repairs, boil water advisories | Water Management |
# | **Day 2-3** | Debris removal from roadways | USACE, FDOT, Counties |
# | **Day 2-3** | Distribution points: water, food, ice, tarps | Logistics, National Guard |
# | **Day 4-5** | Authorize re-entry for evacuated zones | County EM |
# | **Day 4-5** | FEMA Disaster Recovery Centers (DRCs) open | FEMA |
# | **Day 4-5** | Individual Assistance registration begins | FEMA / State |
# | **Day 4-5** | Infrastructure inspection: bridges, dams, levees | USACE, FDOT |
# | **Day 6-7** | Business damage assessment outreach | SBA, Economic Dev |
# | **Day 6-7** | Temporary housing units (if needed) | FEMA, HUD |
# | **Day 6-7** | Transition from response to recovery focus | State EOC |
#
# ### Long-Term Recovery (Week 2+)
#
# | Timeline | Action | Lead Agency |
# |----------|--------|-------------|
# | **Week 2-3** | Major infrastructure repair projects | USACE, FDOT |
# | **Week 2-3** | Schools and public facilities restoration | School Districts |
# | **Week 2-3** | Environmental cleanup and monitoring | DEP, EPA |
# | **Week 4-6** | Public Assistance (PA) program implementation | FEMA |
# | **Week 4-6** | Housing rehabilitation and reconstruction | HUD, SBA |
# | **Week 4-6** | Economic recovery grants and loans | SBA, EDA |
# | **Week 7+** | Hazard mitigation project development | FEMA HMGP |
# | **Week 7+** | Update comprehensive emergency plans | All EM Agencies |
# | **Week 7+** | After-action report and improvement plan | State / FEMA |
# | **Week 7+** | Community resilience building initiatives | Long-Term Recovery |
#
# ---
#
# ## Resource Allocation Priority Matrix
# <div style="margin:6px 0;"><div style="font-size:0.85em; margin-bottom:4px;"><b>Resource Priority Matrix</b></div><img src="data:image/png;base64,..." style="max-width:600px; width:auto; height:auto; display:block;"/></div>
# **Priority Levels:**
# - **1 = LOW** — Not active or minimal need
# - **2 = MEDIUM** — Monitor and prepare
# - **3 = HIGH** — Active response required
# - **4 = CRITICAL** — Maximum priority, immediate action
#
# This matrix shows how resource priorities shift across phases:
# - **Pre-landfall** : Shelter operations and public information are critical
# - **Impact** : Life safety (SAR, medical, communications) is paramount
# - **Day 1** : Power restoration and road clearance become critical
# - **Days 2-7** : Water, food distribution, and debris removal peak
# - **Recovery** : Infrastructure repair and long-term support take priority
#
# ---
#
# ## Crisis Communication Principles
#
# Throughout all phases, follow these communication best practices:
#
# 1. **Be first** : Get information out quickly
# 2. **Be right** : Accuracy is essential; correct errors immediately
# 3. **Be credible** : Tell the truth, even if bad news
# 4. **Express empathy** : Acknowledge impact on those affected
# 5. **Show competence** : Demonstrate effective response
# 6. **Provide action steps** : Tell people what to do
#
# > **Remember** : In absence of information, rumor fills the void.
#
# ---
#
# ## Key Coordinating Agencies
#
# - **FL State Emergency Management (FDEM)** — State lead agency
# - **Florida National Guard** — Military support and logistics
# - **Florida Highway Patrol (FHP)** — Traffic control and security
# - **Florida Dept of Transportation (FDOT)** — Road clearance and infrastructure
# - **Florida Health Department** — Medical coordination
# - **Florida Power & Light / Duke Energy** — Power restoration
# - **American Red Cross** — Sheltering and mass care
# - **FEMA Region IV** — Federal coordination and assistance
# - **US Army Corps of Engineers (USACE)** — Engineering and debris
# - **Urban Search & Rescue (FLTF-1/2)** — Specialized rescue operations
#
# ---
#
# ## Next Steps
#
# 1. **Immediate** : Review and validate the timeline with your specific jurisdiction
# 2. **Today** : Contact state and county emergency management partners
# 3. **This week** : Conduct interagency coordination briefing
# 4. **Ongoing** : Monitor hurricane track updates from NWS/NHC
#
# This plan provides a framework for coordination. Specific actions should be tailored to your jurisdiction's capabilities, the hurricane's projected intensity and path, and available resources.
